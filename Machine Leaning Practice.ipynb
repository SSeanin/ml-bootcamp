# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset('tips')

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.displot(tips['total_bill'], kde=True)

# %%
sns.jointplot(x='total_bill', y='tip', data=tips)

# %%
sns.pairplot(tips, hue='smoker')

# %%
sns.displot(tips['total_bill'])

# %%
sns.rugplot(tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
normal_dist = np.random.randn(50)

# %%
normal_dist
# Out:
# array([-0.47253842,  0.26214598, -1.24358965,  2.20560721,  0.88182372,
#        -0.34937231, -0.26329937,  1.77743157, -0.22744189, -0.76316019,
#         0.23136153, -0.22734336, -1.51173613,  0.57162442,  0.01914573,
#         1.15685859, -0.23856194,  0.82068306, -0.35448319,  1.18869803,
#         0.15630274, -0.3041668 , -0.12017814, -0.65203013, -0.10460794,
#        -0.01798233, -0.05670086, -0.25605653,  0.5049417 ,  0.47774074,
#         0.48721413,  0.37109401,  1.25604943,  1.76228946, -0.09620818,
#        -0.24913242, -0.80188832,  0.06419459,  0.9096658 ,  0.02617734,
#         0.26174681, -0.14825159,  0.90568134, -0.02616754, -1.30864932,
#        -0.14714521, -0.66175604,  0.1202026 , -0.33916619, -0.43250272])

# %%
sns.rugplot(normal_dist)
# Out:
# <AxesSubplot:>

# %%
sns.displot(normal_dist, kde=True)

# %%
uniform = np.random.rand(50)

# %%
uniform
# Out:
# array([0.4559434 , 0.4870988 , 0.56016322, 0.63725814, 0.36807855,
#        0.71126565, 0.05799146, 0.6371656 , 0.86213485, 0.82536002,
#        0.31327743, 0.19830384, 0.85187133, 0.8326543 , 0.83154788,
#        0.15242626, 0.08989212, 0.46856367, 0.75546006, 0.44518185,
#        0.36269056, 0.73259749, 0.54551928, 0.64697069, 0.60578283,
#        0.90080972, 0.18748979, 0.72606148, 0.1180897 , 0.30850331,
#        0.22272975, 0.71922292, 0.34761237, 0.21713489, 0.55216266,
#        0.90097163, 0.94210937, 0.06139784, 0.36270053, 0.98088364,
#        0.47110194, 0.48693875, 0.29771453, 0.21537178, 0.28142743,
#        0.32336902, 0.1553096 , 0.35326953, 0.36342622, 0.14831336])

# %%
sns.displot(uniform, kde=True)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x='sex', y='tip', data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
sns.countplot(x='smoker', data=tips)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.boxplot(x='day', y='total_bill', data=tips, hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day', y='total_bill', data=tips, hue='sex', split=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day', y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day', y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day', y='total_bill', data=tips)
sns.swarmplot(x='day', y='total_bill', data=tips, color='black')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind='strip', jitter=False)

# %%
flights = sns.load_dataset('flights')

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
sns.barplot(x='year', y='passengers', data=flights)
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
flights_pivot = flights.pivot_table(index='month', columns='year', values='passengers')

# %%
sns.heatmap(flights_pivot)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.clustermap(flights_pivot, standard_scale=1)

# %%
sns.jointplot(x='year', y='passengers', data=flights, kind='reg')

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.set_style('white')
sns.set_context('notebook')
sns.countplot(x='sex', data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.lmplot(x='total_bill', y='tip', hue='sex', data=tips, palette='coolwarm')

# %%
plt.figure(figsize=(12, 4))
sns.barplot(x='year', y='passengers', data=flights)
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
normal = np.random.randn(50)

# %%
normal
# Out:
# array([ 2.25811105, -0.44607815,  0.08148841,  1.10243333, -0.38276646,
#        -0.33068059,  1.31238273, -0.97398417,  0.86260882, -0.48687842,
#         0.05446964,  0.632059  , -0.09418248,  0.09208203, -0.63744979,
#         1.03739502, -0.97092319,  1.05082562, -0.49337956, -0.05642868,
#        -0.242004  , -0.23180878,  0.73231824, -0.5578541 , -0.88173103,
#        -0.13425164, -0.20752377,  0.11492405, -1.00303044, -0.24490967,
#         1.28853913, -0.10035983, -1.31378562,  0.6499603 , -1.11179589,
#        -0.34615937, -1.60555751,  2.10365291, -1.07045093,  1.49522321,
#         0.78603643,  1.61342346,  0.38956992,  0.66997616,  0.54599371,
#         0.54561677, -0.04352374, -0.57295523,  0.30376136, -2.36121863])

# %%
standard = np.random.rand(50)

# %%
standard
# Out:
# array([0.02424392, 0.04327856, 0.03147488, 0.41569788, 0.08741011,
#        0.28169985, 0.08576425, 0.46056095, 0.41383204, 0.26417751,
#        0.85366376, 0.28601907, 0.79376625, 0.23629893, 0.7006794 ,
#        0.36402142, 0.2873223 , 0.59327181, 0.44462689, 0.2046831 ,
#        0.42157263, 0.59557532, 0.62133031, 0.41385083, 0.61108572,
#        0.7982251 , 0.33152233, 0.21221167, 0.69456283, 0.21855959,
#        0.53661707, 0.79053574, 0.35004432, 0.79590266, 0.87454323,
#        0.96549765, 0.4200768 , 0.51860231, 0.91343333, 0.28434641,
#        0.48556894, 0.54287689, 0.48770544, 0.59734168, 0.57305999,
#        0.72970572, 0.42468239, 0.58887463, 0.10626148, 0.89954946])

# %%
fig, (axes1, axes2) = plt.subplots(nrows=1, ncols=2)
axes1.plot(sns.displot(normal, kde=True))

sns.displot(standard, kde=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-a625ad167948> in <module>
#       1 fig, (axes1, axes2) = plt.subplots(nrows=1, ncols=2)
# ----> 2 axes1.plot(sns.displot(normal, kde=True))
#       3
#       4 sns.displot(standard, kde=True)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
# -> 1745             self.add_line(line)
#    1746         self._request_autoscale_view(scalex=scalex, scaley=scaley)
#    1747         return lines
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in add_line(self, line)
#    1962             line.set_clip_path(self.patch)
#    1963
# -> 1964         self._update_line_limits(line)
#    1965         if not line.get_label():
# ...
